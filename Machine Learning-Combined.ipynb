# %%
import pandas as pd
import numpy as np
import csv
import requests
import urllib.request, json 
from pprint import pprint
import requests
from bs4 import BeautifulSoup
import pandas as pd
from sklearn.preprocessing import Normalizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.cross_validation import train_test_split
import itertools
from sklearn.naive_bayes import BernoulliNB, GaussianNB
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn import datasets
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('C:/Users/v-ozgenc/Desktop/Out1.csv', index_col = 'Unnamed: 0')
df = df.drop('Difference', 1)
df = df.drop('score', 1)
df = df.dropna()
df = df.drop('week', 1)

# %%
norm = Normalizer()
df[['homeworth', 'awayworth']] = norm.fit_transform(df[['homeworth', 'awayworth']])
df['fullwinner'] = df['winner']
(df[df.winner != 'Draw'])['winner'] = 'No'
df.ix[df.winner != 'Draw', 'winner'] = 'No'
df
# Out:
# c:\users\v-ozgenc\appdata\local\amlworkbench\python\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# c:\users\v-ozgenc\appdata\local\amlworkbench\python\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """
#      Season                              away  \
# 0    2016.0                         BURSASPOR
# 1    2016.0                  ATIKER KONYASPOR
# 2    2016.0                    KASIMPAŞA A.Ş.
# 4    2016.0  AKHISAR BELEDIYE GENÇLIK VE SPOR
# 5    2016.0                     GAZIANTEPSPOR
# 6    2016.0                   FENERBAHÇE A.Ş.
# 7    2016.0         OSMANLISPOR FUTBOL KULÜBÜ
# 8    2016.0              KARDEMIR KARABÜKSPOR
# 9    2016.0                  ANTALYASPOR A.Ş.
# 10   2016.0                     BEŞIKTAŞ A.Ş.
# 11   2016.0                  TRABZONSPOR A.Ş.
# 12   2016.0                  GALATASARAY A.Ş.
# 13   2016.0                    ADANASPOR A.Ş.
# 14   2016.0                    GENÇLERBIRLIĞI
# 15   2016.0              ÇAYKUR RIZESPOR A.Ş.
# 16   2016.0                       KAYSERISPOR
# 17   2016.0             MEDIPOL BAŞAKŞEHIR FK
# 18   2016.0                     GAZIANTEPSPOR
# 19   2016.0                AYTEMIZ ALANYASPOR
# 20   2016.0              KARDEMIR KARABÜKSPOR
# 21   2016.0                    KASIMPAŞA A.Ş.
# 22   2016.0                  GALATASARAY A.Ş.
# 23   2016.0                  ATIKER KONYASPOR
# 24   2016.0                         BURSASPOR
# 25   2016.0  AKHISAR BELEDIYE GENÇLIK VE SPOR
# 26   2016.0         OSMANLISPOR FUTBOL KULÜBÜ
# 27   2016.0                       KAYSERISPOR
# 28   2016.0                  ANTALYASPOR A.Ş.
# 29   2016.0                  TRABZONSPOR A.Ş.
# 30   2016.0              ÇAYKUR RIZESPOR A.Ş.
# ..      ...                               ...
# 582  2015.0                     GAZIANTEPSPOR
# 583  2015.0  AKHISAR BELEDIYE GENÇLIK VE SPOR
# 584  2015.0         OSMANLISPOR FUTBOL KULÜBÜ
# 585  2015.0                     ESKIŞEHIRSPOR
# 586  2015.0                    GENÇLERBIRLIĞI
# 587  2015.0                         BURSASPOR
# 588  2015.0              ÇAYKUR RIZESPOR A.Ş.
# 589  2015.0                  ANTALYASPOR A.Ş.
# 590  2015.0                       KAYSERISPOR
# 591  2015.0                     BEŞIKTAŞ A.Ş.
# 592  2015.0                    KASIMPAŞA A.Ş.
# 593  2015.0                   FENERBAHÇE A.Ş.
# 594  2015.0                  TRABZONSPOR A.Ş.
# 595  2015.0                   TORKU KONYASPOR
# 596  2015.0             MEDIPOL BAŞAKŞEHIR FK
# 5     0.740700     24.6       2625.0       4236.0       home
# 6     0.917843     24.8       3208.0      16485.0       home
# 7     0.804913     25.1      12645.0       3792.0       Draw
# 8     0.268677     25.8      21351.0       4422.0       home
# 9     0.733968     25.4       4541.0      12645.0       home
# 10    0.987121     25.3      15723.0      30448.0       Draw
# 11    0.921120     23.8       4236.0      17252.0       home
# 12    0.932255     25.1       2501.0      21351.0       away
# 13    0.451365     23.7       1416.0       4594.0       Draw
# 14    0.544208     24.1       3792.0       2625.0       Draw
# 15    0.692981     22.6       4422.0       3369.0       home
# 16    0.262299     25.0      16485.0       5524.0       Draw
# 17    0.830225     26.4      16106.0       3208.0       away
# 18    0.897022     24.6       4594.0       4236.0       Draw
# 19    0.724681     25.5       2625.0       4541.0       Draw
# 20    0.199302     25.8      30448.0       4422.0       home
# 21    0.476147     23.4       3208.0       1416.0       home
# 22    0.942539     25.1       5524.0      21351.0       Draw
# 23    0.566696     25.3      12645.0      15723.0       away
# 24    0.278854     24.4      16485.0      16106.0       away
# 25    0.822758     26.7       3369.0       2501.0       home
# 26    0.508744     25.1      17252.0       3792.0       away
# 27    0.683396     25.0      16106.0       5524.0       home
# 28    0.757002     25.4       4422.0      12645.0       home
# 29    0.927473     23.8       4541.0      17252.0       home
# 30    0.258964     22.6      21351.0       3369.0       home
# ..         ...      ...          ...          ...        ...
# 582   0.184513     23.5      28589.0       3065.0       home
# 583   0.649823     26.9       4881.0       2394.0       Draw
# 584   0.665571     26.6       1950.0       4186.0       Draw
# 585   0.798362     23.9       3065.0       6815.0       Draw
# 586   0.713738     25.4       4881.0       2565.0       home
# 587   0.899441     23.9       4186.0      11245.0       Draw
# 588   0.245939     24.3       7696.0       3314.0       home
# 589   0.907198     25.1       5116.0       9362.0       away
# 590   0.703140     24.4       2394.0       4251.0       Draw
# 591   0.705280     24.5      18996.0      18668.0       away
# 592   0.822314     25.1      15871.0       1950.0       home
# 593   0.971123     24.5       2716.0      28589.0       home
# 594   0.934586     23.5       9362.0       7696.0       home
# 595   0.352798     25.8      11245.0      15871.0       Draw
# 596   0.702482     26.3       6815.0       2716.0       away
# 597   0.763662     27.0       4251.0       4881.0       Draw
# 598   0.747151     23.5       3314.0       3065.0       home
# 599   0.422478     25.0       1950.0       5116.0       home
# 600   0.966793     25.6       2394.0      18996.0       away
# 601   0.214225     25.4      28589.0       2565.0       home
# 602   0.305631     26.6      18668.0       4186.0       home
# 603   0.969230     23.9       5116.0      11245.0       away
# 604   0.562192     24.3       2716.0       3314.0       home
# 605   0.970353     24.5      15871.0      18668.0       home
# 606   0.977615     24.5       4881.0      28589.0       Draw
# 607   0.637651     26.9       4186.0       2394.0       home
# 608   0.252900     24.4      18996.0       4251.0       home
# 609   0.800255     25.1       3065.0       9362.0       home
# 610   0.354150     25.1       7696.0       1950.0       away
# 611   0.750288     23.9       2565.0       6815.0       home
#
# [611 rows x 19 columns]

# %%
winner = df['winner']
df = df.drop('winner', 1)
fullwinner = df['fullwinner']
df = df.drop('fullwinner', 1)
columns_to_encode = list(df.select_dtypes(include=['category','object']))
for column_to_encode in columns_to_encode:
    dummies = pd.get_dummies(df[column_to_encode])
    one_hot_col_names = []
    for col_name in list(dummies.columns):
        one_hot_col_names.append(column_to_encode + '_' + col_name)
    dummies.columns = one_hot_col_names
    df = df.drop(column_to_encode, axis=1)
    df = df.join(dummies)
df['winner'] = winner
df['fullwinner'] = fullwinner
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\v-ozgenc\appdata\local\amlworkbench\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fullwinner'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-1698abf99669> in <module>()
#       1 winner = df['winner']
#       2 df = df.drop('winner', 1)
# ----> 3 fullwinner = df['fullwinner']
#       4 df = df.drop('fullwinner', 1)
#       5 columns_to_encode = list(df.select_dtypes(include=['category','object']))
#
# c:\users\v-ozgenc\appdata\local\amlworkbench\python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# c:\users\v-ozgenc\appdata\local\amlworkbench\python\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# c:\users\v-ozgenc\appdata\local\amlworkbench\python\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# c:\users\v-ozgenc\appdata\local\amlworkbench\python\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# c:\users\v-ozgenc\appdata\local\amlworkbench\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fullwinner'

# %%
model = BernoulliNB()
train, test = train_test_split(df,random_state = 17, test_size = 0.3)
target = train['winner'].values
finaltarget = train['fullwinner'].values
train = train.drop('winner', 1)
train = train.drop('fullwinner', 1)
train = train.values
expected = test['winner'].values
test = test.drop('winner', 1)
finalexpected = test['fullwinner'].values
test = test.drop('fullwinner', 1)
model.fit(train, target)
predicted = model.predict(test)
print("Accuracy of BernoulliNB", accuracy_score(expected, predicted))
new_df = df
new_df = new_df.drop('winner', 1)
new_df = new_df.drop('fullwinner', 1)
pre_predict = model.predict(new_df)
new_df['predicted'] = pre_predict
new_df['fullwinner'] = fullwinner
new_df
# Out:
# Accuracy of BernoulliNB 0.809782608696
#      Season  homeATT  homeMID  homeDEF  homeOVR  awayATT  awayMID  awayDEF  \
# 0    2016.0     71.0     67.0     69.0     69.0     70.0     72.0     71.0
# 1    2016.0     76.0     68.0     68.0     69.0     72.0     70.0     71.0
# 2    2016.0     73.0     74.0     76.0     74.0     69.0     71.0     71.0
# 4    2016.0     73.0     72.0     70.0     71.0     70.0     71.0     71.0
# 5    2016.0     69.0     70.0     70.0     70.0     71.0     69.0     68.0
# 6    2016.0     78.0     75.0     73.0     75.0     80.0     77.0     78.0
# 7    2016.0     81.0     71.0     72.0     71.0     74.0     74.0     72.0
# 8    2016.0     76.0     77.0     74.0     76.0     71.0     70.0     70.0
# 9    2016.0     73.0     70.0     71.0     70.0     81.0     71.0     72.0
# 10   2016.0     72.0     70.0     71.0     71.0     78.0     78.0     76.0
# 11   2016.0     71.0     69.0     68.0     70.0     73.0     74.0     76.0
# 12   2016.0     70.0     71.0     71.0     70.0     76.0     77.0     74.0
# 13   2016.0     69.0     71.0     71.0     70.0     71.0     67.0     69.0
# 14   2016.0     74.0     74.0     72.0     73.0     69.0     70.0     70.0
# 15   2016.0     71.0     70.0     70.0     70.0     76.0     68.0     68.0
# 16   2016.0     80.0     77.0     78.0     77.0     73.0     72.0     70.0
# 17   2016.0     70.0     72.0     71.0     72.0     78.0     75.0     73.0
# 18   2016.0     71.0     67.0     69.0     69.0     71.0     69.0     68.0
# 19   2016.0     69.0     70.0     70.0     70.0     73.0     70.0     71.0
# 20   2016.0     78.0     78.0     76.0     78.0     71.0     70.0     70.0
# 21   2016.0     78.0     75.0     73.0     75.0     69.0     71.0     71.0
# 22   2016.0     73.0     72.0     70.0     71.0     76.0     77.0     74.0
# 23   2016.0     81.0     71.0     72.0     71.0     72.0     70.0     71.0
# 24   2016.0     80.0     77.0     78.0     77.0     70.0     72.0     71.0
# 25   2016.0     76.0     68.0     68.0     69.0     70.0     71.0     71.0
# 26   2016.0     73.0     74.0     76.0     74.0     74.0     74.0     72.0
# 27   2016.0     70.0     72.0     71.0     72.0     73.0     72.0     70.0
# 28   2016.0     71.0     70.0     70.0     70.0     81.0     71.0     72.0
# 29   2016.0     73.0     70.0     71.0     70.0     73.0     74.0     76.0
# 30   2016.0     76.0     77.0     74.0     76.0     76.0     68.0     68.0
# ..      ...      ...      ...      ...      ...      ...      ...      ...
#
# 16      71.0   0.964987     ...                     0
# 17      75.0   0.557429     ...                     0
# 18      70.0   0.441985     ...                     0
# 19      70.0   0.689084     ...                     0
# 20      70.0   0.979938     ...                     0
# 21      70.0   0.879366     ...                     0
# 22      76.0   0.334097     ...                     1
# 23      71.0   0.823927     ...                     0
# 24      72.0   0.960333     ...                     0
# 25      70.0   0.568392     ...                     0
# 26      73.0   0.860918     ...                     0
# 27      71.0   0.730048     ...                     0
# 28      71.0   0.653412     ...                     0
# 29      74.0   0.373889     ...                     0
# 30      69.0   0.965887     ...                     0
# ..       ...        ...     ...                   ...
# 582     69.0   0.982830     ...                     0
# 583     70.0   0.760085     ...                     0
# 584     71.0   0.746335     ...                     0
# 585     68.0   0.602178     ...                     0
# 586     70.0   0.700413     ...                     0
# 587     72.0   0.437041     ...                     0
# 588     69.0   0.969285     ...                     0
# 589     71.0   0.420703     ...                     0
# 590     69.0   0.711051     ...                     0
# 591     77.0   0.708929     ...                     0
# 592     70.0   0.569034     ...                     0
# 593     77.0   0.238581     ...                     0
# 594     73.0   0.355738     ...                     0
# 595     70.0   0.935700     ...                     0
# 596     71.0   0.711702     ...                     0
# 597     68.0   0.645617     ...                     1
# 598     69.0   0.664655     ...                     0
# 599     67.0   0.906373     ...                     0
# 600     75.0   0.255560     ...                     0
# 601     70.0   0.976784     ...                     0
# 602     71.0   0.952150     ...                     0
# 603     72.0   0.246157     ...                     0
# 604     69.0   0.827007     ...                     0
# 605     77.0   0.241692     ...                     0
# 606     77.0   0.210404     ...                     0
# 607     70.0   0.770325     ...                     0
# 608     69.0   0.967493     ...                     0
# 609     71.0   0.599660     ...                     0
# 610     70.0   0.935189     ...                     0
# 611     68.0   0.661111     ...                     0
#
#      home_MEDICANA SIVASSPOR  home_MEDIPOL BAŞAKŞEHIR FK  \
# 0                          0                           0
# 1                          0                           0
# 2                          0                           0
# 4                          0                           0
# 5                          0                           0
# 6                          0                           1
# 7                          0                           0
# 8                          0                           0
# 9                          0                           0
# 10                         0                           0
# 11                         0                           0
# 12                         0                           0
# 13                         0                           0
# 14                         0                           0
# 15                         0                           0
# 16                         0                           0
# 17                         0                           0
# 18                         0                           0
# 19                         0                           0
# 20                         0                           0
# 21                         0                           1
# 22                         0                           0
# 23                         0                           0
# 24                         0                           0
# 25                         0                           0
# 26                         0                           0
# 27                         0                           0
# 28                         0                           0
# 29                         0                           0
# 30                         0                           0
# ..                       ...                         ...
# 582                        0                           0
# 583                        1                           0
# 584                        0                           0
# 585                        0                           0
# 586                        1                           0
# 587                        0                           0
# 588                        0                           0
# 589                        0                           0
# 590                        0                           0
# 591                        0                           0
# 592                        0                           0
# 593                        0                           1
# 594                        0                           0
# 595                        0                           0
# 596                        0                           0
# 597                        0                           0
# 598                        0                           0
# 599                        0                           0
# 600                        0                           0
# 601                        0                           0
# 602                        0                           0
# 603                        0                           0
# 604                        0                           1
# 605                        0                           0
# 606                        1                           0
# 607                        0                           0
# 608                        0                           0
# 609                        0                           0
# 610                        0                           0
# 611                        0                           0
#
#      home_MERSIN IDMANYURDU  home_OSMANLISPOR FUTBOL KULÜBÜ  \
# 0                         0                               0
# 1                         0                               0
# 2                         0                               0
#
# 20          No        home
# 21          No        home
# 22          No        Draw
# 23          No        away
# 24          No        away
# 25          No        home
# 26          No        away
# 27          No        home
# 28          No        home
# 29          No        home
# 30          No        home
# ..         ...         ...
# 582         No        home
# 583       Draw        Draw
# 584         No        Draw
# 585         No        Draw
# 586         No        home
# 587         No        Draw
# 588         No        home
# 589         No        away
# 590         No        Draw
# 591         No        away
# 592         No        home
# 593         No        home
# 594         No        home
# 595         No        Draw
# 596         No        away
# 597         No        Draw
# 598         No        home
# 599         No        home
# 600         No        away
# 601         No        home
# 602         No        home
# 603         No        away
# 604         No        home
# 605         No        home
# 606         No        Draw
# 607         No        home
# 608         No        home
# 609         No        home
# 610         No        away
# 611         No        home
#
# [611 rows x 61 columns]

# %%
train_df = new_df[new_df.predicted != 'Draw']
train_df = train_df[train_df.fullwinner != 'Draw']

model1 = BernoulliNB()
trainfin, testfin = train_test_split(train_df,random_state = 17, test_size = 0.3)
trainfin = trainfin.drop('predicted', 1)
targetfin = trainfin['fullwinner']
trainfin = trainfin.drop('fullwinner', 1)
trainfin = trainfin.values

model1.fit(trainfin, targetfin)
forpred = new_df[new_df.predicted != 'Draw']
forpred = forpred.drop('predicted', 1)
forpred = forpred.drop('fullwinner', 1)
fin = model1.predict(forpred)

new_df.ix[new_df.predicted != 'Draw', 'predicted'] = fin
print("Accuracy of BernoulliNB", accuracy_score(new_df.fullwinner, new_df.predicted))
# Out:
# Accuracy of BernoulliNB 0.559738134206
# c:\users\v-ozgenc\appdata\local\amlworkbench\python\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
model = OneVsRestClassifier(LinearSVC(random_state=0))
train, test = train_test_split(df,random_state = 17, test_size = 0.3)
    
target = train['winner'].values
train = train.drop('winner', 1)
train = train.values
expected = test['winner'].values
test = test.drop('winner', 1)
model.fit(train, target)
predicted = model.predict(test)
print("Accuracy of OneVsRestClassifier", accuracy_score(expected, predicted))
# Out:
# Accuracy of OneVsRestClassifier 0.20652173913

# %%
model = KNeighborsClassifier(n_neighbors=4)
train, test = train_test_split(df, test_size = 0.3)
    
target = train['winner'].values
train = train.drop('winner', 1)
train = train.values
expected = test['winner'].values
test = test.drop('winner', 1)
model.fit(train, target)
predicted = model.predict(test)
print("Accuracy of OneVsRestClassifier", accuracy_score(expected, predicted))
# Out:
# Accuracy of OneVsRestClassifier 0.413043478261

# %%
df = df.drop('winner', 1)
model = BernoulliNB()
train, test = train_test_split(df, random_state = 17, test_size = 0.3)
    
target = train['fullwinner'].values
train = train.drop('fullwinner', 1)
train = train.values
expected = test['fullwinner'].values
test = test.drop('fullwinner', 1)
model.fit(train, target)
predicted = model.predict(test)
print("Accuracy of BernoulliNB", accuracy_score(expected, predicted))
# Out:
# Accuracy of BernoulliNB 0.521739130435

# %%
model = DecisionTreeClassifier(random_state=0)
train, test = train_test_split(df, test_size = 0.3)
    
target = train['winner'].values
train = train.drop('winner', 1)
train = train.values
expected = test['winner'].values
test = test.drop('winner', 1)
model.fit(train, target)
predicted = model.predict(test)
print("Accuracy of OneVsRestClassifier", accuracy_score(expected, predicted))
# Out:
# Accuracy of OneVsRestClassifier 0.391304347826

# %%
import itertools
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.metrics import confusion_matrix

class_names = ['Draw', 'home', 'away']

# Split the data into a training set and a test set
y_test = new_df.fullwinner 

# Run classifier, using a model that is too regularized (C too low) to see
# the impact on the results
y_pred = new_df.predicted


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[  6  44  95]
#  [  0  96  89]
#  [  1  40 240]]
# Normalized confusion matrix
# [[ 0.04  0.3   0.66]
#  [ 0.    0.52  0.48]
#  [ 0.    0.14  0.85]]
